# %%
import pandas as pd

# %%
data = pd.read_csv('utxodump.csv')
data
# Out:
# C:\Users\tw251\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (0,2,3,4,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                  0  \
# 0            count
# 1                1
# 2                2
# 3                3
# 4                4
# ...            ...
# 67121805  67121805
# 67121806  67121806
# 67121807  67121807
# 67121808  67121808
# 67121809  67121809
#
#          ae9a1a238d4af19caf442b49961643a9fda2b852bf0d0a0a2a64a81c03000000  \
# 0                                                      txid
# 1         cabdde380408ea8950a478c72a3f718d0a551192baaa63...
# 2         bfdb7bef090335627cbce4b2da36b15d0862f19b02d5db...
# 3         bffa48f172155f909d36d4904f917e64e17c73b81e5361...
# 4         033e83e3204b0cc28724e147f6fd140529b2537249f9c6...
# ...                                                     ...
# ...
